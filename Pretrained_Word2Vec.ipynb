# %%
from gensim.models import keyedvectors

# %%
path = r"D:\DATA SCIENCE\NLP\Practice\GoogleNews-vectors-negative300.bin.gz"
model = keyedvectors.load_word2vec_format(path,binary = True)

# %%
model["bad"]
# Out:
# array([ 0.06298828,  0.12451172,  0.11328125,  0.07324219,  0.03881836,
#         0.07910156,  0.05078125,  0.171875  ,  0.09619141,  0.22070312,
#        -0.04150391, -0.09277344, -0.02209473,  0.14746094, -0.21582031,
#         0.15234375,  0.19238281, -0.05078125, -0.11181641, -0.3203125 ,
#         0.00506592,  0.15332031, -0.02563477, -0.0234375 ,  0.36328125,
#         0.20605469,  0.04760742, -0.02624512,  0.09033203,  0.00457764,
#        -0.15332031,  0.06591797,  0.3515625 , -0.12451172,  0.03015137,
#         0.16210938,  0.00242615, -0.02282715,  0.02978516,  0.00531006,
#         0.25976562, -0.22460938,  0.29492188, -0.18066406,  0.07910156,
#         0.02282715,  0.12109375, -0.17382812, -0.03735352, -0.06933594,
#        -0.21972656,  0.1875    , -0.03320312, -0.06225586, -0.04492188,
#         0.11621094, -0.23339844, -0.11669922,  0.09814453, -0.11962891,
#         0.13964844,  0.28710938, -0.26953125, -0.05493164,  0.03112793,
# ...

# %%
model["not"]
# Out:
# array([ 0.08496094, -0.09521484,  0.11914062,  0.11181641, -0.11132812,
#         0.04980469,  0.11425781, -0.09863281,  0.09960938, -0.04150391,
#         0.01287842, -0.18164062, -0.11621094,  0.02380371, -0.1640625 ,
#         0.12695312,  0.12060547,  0.00946045,  0.04150391, -0.09521484,
#        -0.12988281, -0.11523438,  0.07519531, -0.04980469,  0.06591797,
#        -0.02905273, -0.08984375,  0.08447266, -0.04785156, -0.02709961,
#        -0.10302734,  0.11083984,  0.01422119, -0.09863281,  0.04125977,
#         0.07226562,  0.10986328,  0.01135254, -0.01483154,  0.0456543 ,
#         0.140625  ,  0.14648438,  0.25976562, -0.16796875, -0.00145721,
#        -0.02148438,  0.0189209 ,  0.04003906,  0.0559082 ,  0.03808594,
#         0.00202942,  0.07128906, -0.05249023, -0.02783203,  0.11132812,
#         0.11914062, -0.05249023, -0.07910156,  0.10302734, -0.11816406,
#         0.03662109,  0.13671875, -0.09033203, -0.0703125 , -0.0390625 ,
# ...

# %%
model["good"]
# Out:
# array([ 0.04052734,  0.0625    , -0.01745605,  0.07861328,  0.03271484,
#        -0.01263428,  0.00964355,  0.12353516, -0.02148438,  0.15234375,
#        -0.05834961, -0.10644531,  0.02124023,  0.13574219, -0.13183594,
#         0.17675781,  0.27148438,  0.13769531, -0.17382812, -0.14160156,
#        -0.03076172,  0.19628906, -0.03295898,  0.125     ,  0.25390625,
#         0.12695312, -0.15234375,  0.03198242,  0.01135254, -0.01361084,
#        -0.12890625,  0.01019287,  0.23925781, -0.08447266,  0.140625  ,
#         0.13085938, -0.04516602,  0.06494141,  0.02539062,  0.05615234,
#         0.24609375, -0.20507812,  0.23632812, -0.00860596, -0.02294922,
#         0.05078125,  0.10644531, -0.03564453,  0.08740234, -0.05712891,
#         0.08496094,  0.23535156, -0.10107422, -0.03564453, -0.04736328,
#         0.04736328, -0.14550781, -0.10986328,  0.14746094, -0.23242188,
#        -0.07275391,  0.19628906, -0.37890625, -0.07226562,  0.04833984,
# ...

# %%
model["bogus"]
# Out:
# array([ 9.81445312e-02,  1.25000000e-01,  8.10546875e-02, -1.88476562e-01,
#        -1.82617188e-01,  1.77734375e-01, -2.16796875e-01,  2.50000000e-01,
#        -2.97851562e-02,  3.58886719e-02,  4.49218750e-02, -2.55859375e-01,
#        -2.12890625e-01,  3.41796875e-01, -3.28125000e-01,  1.02050781e-01,
#         7.37304688e-02, -6.39648438e-02, -4.61425781e-02, -1.03027344e-01,
#         1.66015625e-01, -9.33837891e-03,  7.47070312e-02,  9.91210938e-02,
#        -2.51464844e-02, -1.93359375e-01, -3.18908691e-03, -7.66601562e-02,
#         2.16796875e-01,  8.00781250e-02, -4.85839844e-02, -1.98242188e-01,
#        -1.18652344e-01, -4.98046875e-02,  6.54296875e-02, -7.27539062e-02,
#        -7.81250000e-03, -7.81250000e-03,  1.60156250e-01, -4.58984375e-02,
#         2.60009766e-02, -1.10839844e-01,  8.39843750e-02,  1.89208984e-03,
#        -7.12890625e-02, -3.32031250e-01, -7.08007812e-02,  2.83203125e-01,
# ...

# %%
model["terrible"]
# Out:
# array([ 0.1640625 ,  0.19238281,  0.09228516,  0.13085938,  0.07519531,
#         0.11035156,  0.04785156,  0.00055313,  0.27148438,  0.20800781,
#        -0.00183868, -0.16015625, -0.19921875, -0.0267334 ,  0.13964844,
#         0.16210938,  0.18652344,  0.04931641, -0.08642578, -0.22070312,
#         0.07470703,  0.30859375,  0.01757812, -0.06933594,  0.30664062,
#         0.09667969,  0.13183594,  0.0168457 , -0.0037384 , -0.11035156,
#        -0.30078125, -0.10107422,  0.09570312,  0.00257874, -0.02307129,
#         0.1484375 ,  0.10986328,  0.03564453, -0.11572266,  0.11474609,
#         0.25585938, -0.00726318,  0.48828125, -0.421875  ,  0.12792969,
#         0.10693359,  0.25390625,  0.02209473, -0.07080078, -0.13574219,
#        -0.00567627,  0.24023438,  0.01019287,  0.00305176, -0.06201172,
#        -0.11523438, -0.203125  , -0.18652344,  0.10742188, -0.05664062,
#        -0.00418091,  0.43359375, -0.04663086, -0.13964844, -0.00061417,
# ...

# %%
model["horrible"]
# Out:
# array([ 9.96093750e-02,  1.33789062e-01,  1.04980469e-01,  1.17675781e-01,
#         1.77001953e-02,  1.50390625e-01,  1.21093750e-01, -1.92871094e-02,
#         2.67578125e-01,  1.47460938e-01, -2.18505859e-02, -1.21582031e-01,
#        -1.17187500e-01, -5.82885742e-03,  1.38671875e-01,  1.47460938e-01,
#         1.32812500e-01, -6.43920898e-03, -1.35742188e-01, -1.79687500e-01,
#         6.93359375e-02,  2.50000000e-01,  5.51757812e-02, -1.16210938e-01,
#         2.04101562e-01,  6.78710938e-02,  1.70898438e-01,  5.78613281e-02,
#         3.83300781e-02, -1.04492188e-01, -2.67578125e-01, -3.85742188e-02,
#         1.53320312e-01, -2.12402344e-02,  4.54711914e-03,  1.76757812e-01,
#         1.80664062e-01, -8.34960938e-02, -5.98144531e-02,  9.52148438e-02,
#         3.12500000e-01, -8.49609375e-02,  4.76562500e-01, -3.90625000e-01,
#         8.20312500e-02,  8.39843750e-02,  2.16796875e-01,  9.27734375e-02,
# ...

# %%
model.similarity("bad","horrible")
# Out:
# 0.6702599

# %%
model.similarity("bad","worse")
# Out:
# 0.51410466

# %%
model.similarity("bad","good")
# Out:
# 0.7190051

# %%
model.most_similar("good")
# Out:
# [('great', 0.7291509509086609),
#  ('bad', 0.7190050482749939),
#  ('terrific', 0.688911497592926),
#  ('decent', 0.6837348937988281),
#  ('nice', 0.6836092472076416),
#  ('excellent', 0.6442928910255432),
#  ('fantastic', 0.6407778263092041),
#  ('better', 0.6120728850364685),
#  ('solid', 0.5806034803390503),
#  ('lousy', 0.576420247554779)]

# %%
model.most_similar("king")
# Out:
# [('kings', 0.7138045430183411),
#  ('queen', 0.6510956287384033),
#  ('monarch', 0.6413194537162781),
#  ('crown_prince', 0.6204219460487366),
#  ('prince', 0.6159993410110474),
#  ('sultan', 0.5864822864532471),
#  ('ruler', 0.5797566771507263),
#  ('princes', 0.5646552443504333),
#  ('Prince_Paras', 0.5432944297790527),
#  ('throne', 0.5422104597091675)]

# %%
model.doesnt_match(['bad','terrible','horrible','good'])
# Out:
# 'good'

# %%
model.doesnt_match(['bad','terrible','horrible','king'])
# Out:
# 'king'
